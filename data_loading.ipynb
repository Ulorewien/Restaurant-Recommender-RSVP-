# %%
import pandas as pd
import gzip
import json

# %%
# Open the compressed file using gzip
with gzip.open("meta-California.json.gz", 'rt', encoding='utf-8') as file:
    # Read the JSON content into a DataFrame
    df = pd.read_json(file, lines=True)

# %%
meta_business_df = df

# %%
# Read the JSON content into a DataFrame
google_review_df = pd.read_json("google_review.json", lines=True)

# %%
google_review_df.head(5)
# Out:
#                 business_id       user_id  rating  \
# 0  605730f68cd0e3d69a52284b  1.138909e+20       4
# 1  605730f68cd0e3d69a52284b  1.001584e+20       5
# 2  605730f68cd0e3d69a52284b  1.134952e+20       2
# 3  605730f68cd0e3d69a52284b  1.112595e+20       3
# 4  605730f68cd0e3d69a52284b  1.042855e+20       5
#
#                                          review_text  \
# 0  We came for a birthday brunch and this place i...
# 1  Cool place to hang out, have drinks.  There is...
# 2  This place doesn’t rock the senses when it com...
# 3  Pretty cool place to hang out with friends and...
# 4  We saw this place the other day when we had re...
#
#                                                 pics
# 0  [{'id': 'AF1QipPrls2G30PS3tyC55KBxUrKgy3ER0AB5...
# 1  [{'id': 'AF1QipPj8FEVZrdpTZmRdjoOtzQyfGYSwJ0Ub...
# 2  [{'id': 'AF1QipOP5poDTRQ4XXIM11buv5x9Ae-BNXwcq...
# 3  [{'id': 'AF1QipMq84NEaCMdQtfrELbudJdQbTILp_5I_...
# 4  [{'id': 'AF1QipOTCVzPHHWTiQO_2UZNVeG5KMbcki6d5...

# %%
meta_business_df.head(10)
# Out:
#                                        name  \
# 0                              City Textile
# 1                              San Soo Dang
# 2                              Nova Fabrics
# 3                          Nobel Textile Co
# 4             Matrix International Textiles
# 5                              Vons Chicken
# 6  Black Tie Ski Rental Delivery of Mammoth
# 7                           Angel-A Massage
# 8                       Dunn-Edwards Paints
# 9                             Elite Massage
#
#                                              address  \
# 0  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 1  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 2  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 3  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 4  Matrix International Textiles, 1363 S Bonnie B...
# 5  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 6  Black Tie Ski Rental Delivery of Mammoth, 501 ...
# ...
